# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:10, 3.10MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6441 0.1545 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6156 0.0777 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4944 0.0778 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5805 0.0773 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4963 0.0773 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5911 0.0774 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5604 0.0773 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5400 0.0765 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4935 0.0776 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4452 0.0771 sec/batch
# Nearest to zero: abaddon, engrams, grown, zionists, publication, owners, inseparable, tiptree,
# Nearest to one: remey, dumb, postscript, jurors, mister, motorcycles, prot, climatology,
# Nearest to six: sefirot, evaporated, regiments, layperson, nephites, entomologist, provable, anjouan,
# Nearest to that: multilateral, rpc, flamboyant, owls, arche, micah, batted, kotoku,
# Nearest to there: intention, probation, clippers, diyala, empties, avedon, fushimi, gearloose,
# Nearest to years: leonel, wolfowitz, producer, digests, balzac, chromatid, ackerman, assault,
# Nearest to and: simo, show, conformed, nightly, vets, imt, serling, day,
# Nearest to s: broz, gall, sleng, humid, nadph, mississippians, sanctuaries, vasopressin,
# Nearest to channel: rainstorm, bolster, leftarrow, amusements, champaign, tidy, demobilization, lollardy,
# Nearest to stage: yerushalayim, aquileia, fainting, siamese, ridge, blurry, kc, pear,
# Nearest to brother: rebuffed, eating, blaurock, ansel, bovines, metaphysics, productions, refutes,
# Nearest to prince: marshalling, satsuma, lymphomas, wein, passively, assumption, lighthouse, cvs,
# Nearest to something: portuguesa, charting, escapement, kb, satyr, protolanguage, mailing, connectives,
# Nearest to hit: dazzle, carriage, storing, tiberian, histology, barton, diophantus, nu,
# Nearest to centre: v, claudia, khomeini, thatch, sharman, hanged, goya, convulsions,
# Nearest to magazine: gymnast, spine, farming, lashed, pave, insanity, arran, ripple,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4622 0.0789 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3942 0.0778 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3263 0.0772 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2265 0.0776 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1894 0.0776 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1547 0.0782 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0812 0.0777 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0592 0.0771 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0173 0.0770 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9661 0.0781 sec/batch
# Nearest to zero: abaddon, grown, engrams, owners, satan, publication, senses, increased,
# Nearest to one: followed, dumb, mister, structural, prot, remey, defence, dunkirk,
# Nearest to six: sefirot, regiments, evaporated, offer, cbm, advances, official, layperson,
# Nearest to that: isn, flamboyant, physics, rpc, multilateral, batted, class, bight,
# Nearest to there: intention, probation, computer, find, clippers, genres, trigonometric, satisfy,
# Nearest to years: preferred, producer, wolfowitz, september, digests, travelled, australia, clerk,
# Nearest to and: show, day, application, simo, nightly, credits, asserts, electronic,
# Nearest to s: because, freund, nadph, gall, broz, vasopressin, simplest, controversially,
# Nearest to channel: rainstorm, bolster, lollardy, leftarrow, amusements, objects, tidy, gave,
# Nearest to stage: ridge, coherent, siamese, pear, lightest, blurry, yerushalayim, rotating,
# Nearest to brother: eating, rebuffed, productions, group, writings, metaphysics, investigate, ansel,
# Nearest to prince: marshalling, satsuma, assumption, passively, wein, lymphomas, metcalfe, lighthouse,
# Nearest to something: portuguesa, mailing, almost, connectives, proper, kb, charting, escapement,
# Nearest to hit: storing, carriage, scripted, acting, dazzle, barton, alveolar, histology,
# Nearest to centre: v, occupies, sharman, claudia, thatch, talented, accumulated, khomeini,
# Nearest to magazine: farming, principles, throws, spine, n, gymnast, westminster, eurasia,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9511 0.0779 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8898 0.0768 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8764 0.0773 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8407 0.0778 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8081 0.0770 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8355 0.0782 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7945 0.0773 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8020 0.0771 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7736 0.0777 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7591 0.0776 sec/batch
# Nearest to zero: abaddon, grown, engrams, zionists, owners, satan, tokens, amity,
# Nearest to one: six, prot, followed, dumb, reversion, winnie, mister, rapprochement,
# Nearest to six: sefirot, evaporated, one, layperson, vietnamese, entomologist, peoples, negotiations,
# Nearest to that: flamboyant, isn, multilateral, rpc, technologically, proteins, stemmed, kotoku,
# Nearest to there: intention, genres, probation, empties, computer, clippers, banner, trigonometric,
# Nearest to years: preferred, producer, digests, wolfowitz, september, travelled, australia, clerk,
# Nearest to and: simo, show, conformed, vets, day, vikings, restores, nightly,
# Nearest to s: humid, gall, nadph, broz, because, freund, controversially, sometime,
# Nearest to channel: rainstorm, bolster, lollardy, tidy, leftarrow, sanctify, demobilization, amusements,
# Nearest to stage: ridge, lightest, rotating, coherent, blurry, siamese, pear, yerushalayim,
# Nearest to brother: eating, writings, rebuffed, investigate, melton, ansel, metaphysics, productions,
# Nearest to prince: marshalling, passively, satsuma, assumption, wein, metcalfe, turmoil, distort,
# Nearest to something: mailing, portuguesa, charting, kb, escapement, connectives, proper, bantu,
# Nearest to hit: storing, carriage, tiberian, dazzle, cooperation, scripted, barton, nu,
# Nearest to centre: v, occupies, claudia, sharman, khomeini, goodwill, thatch, hanged,
# Nearest to magazine: spine, principles, farming, gymnast, westminster, throws, n, insanity,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7832 0.0781 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7428 0.0773 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7228 0.0780 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7435 0.0778 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7446 0.0783 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6920 0.0776 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7129 0.0777 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7337 0.0780 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6721 0.0776 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6856 0.0777 sec/batch
# Nearest to zero: five, abaddon, engrams, est, zionists, grown, nine, four,
# Nearest to one: six, nine, five, winnie, four, seven, russian, lakers,
# Nearest to six: one, entomologist, evaporated, sefirot, seven, baptiste, obispo, layperson,
# Nearest to that: flamboyant, rpc, multilateral, isn, harnessed, stemmed, anglia, sharada,
# Nearest to there: intention, genres, terminates, empties, trigonometric, find, clippers, diyala,
# Nearest to years: september, wolfowitz, digests, producer, travelled, algeria, five, preferred,
# Nearest to and: simo, show, conformed, day, vikings, restores, vets, zed,
# Nearest to s: humid, broz, nadph, gall, because, spellman, controversially, lovers,
# Nearest to channel: rainstorm, bolster, champaign, lollardy, amusements, demobilization, sanctify, dubois,
# Nearest to stage: yerushalayim, ridge, siamese, blurry, lightest, balearic, pear, testimonium,
# Nearest to brother: writings, nicholson, blaurock, melton, rainier, eating, nurses, rebuffed,
# Nearest to prince: marshalling, satsuma, passively, wein, metcalfe, chapelle, lymphomas, cvs,
# Nearest to something: mailing, portuguesa, escapement, charting, kb, connectives, transformational, biafra,
# Nearest to hit: storing, tiberian, carriage, alveolar, dazzle, barton, acceded, nu,
# Nearest to centre: occupies, v, claudia, khomeini, hanged, goodwill, sharman, nss,
# Nearest to magazine: spine, gymnast, arran, principles, farming, insanity, westminster, pave,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6788 0.0794 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6996 0.0774 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6345 0.0786 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6328 0.0771 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6238 0.0774 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6359 0.0782 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6049 0.0583 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5496 0.0783 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5024 0.0780 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4956 0.0778 sec/batch
# Nearest to zero: five, est, abaddon, two, engrams, four, zionists, lenape,
# Nearest to one: six, nine, four, winnie, russian, five, lakers, heinrich,
# Nearest to six: one, entomologist, baptiste, seven, evaporated, obispo, prelate, sefirot,
# Nearest to that: flamboyant, rpc, isn, stemmed, harnessed, sharada, intuition, multilateral,
# Nearest to there: intention, genres, terminates, find, trigonometric, empties, clippers, computer,
# Nearest to years: wolfowitz, september, digests, travelled, leonel, balzac, algeria, crusader,
# Nearest to and: conformed, simo, show, zed, day, crozier, ignacy, harwood,
# Nearest to s: broz, humid, gall, nadph, barrie, anhalt, undeniably, spellman,
# Nearest to channel: rainstorm, bolster, champaign, leftarrow, lollardy, sanctify, demobilization, amusements,
# Nearest to stage: yerushalayim, ridge, siamese, rotating, exception, balearic, blurry, lp,
# Nearest to brother: writings, rainier, nicholson, blaurock, count, melton, rebuffed, beatrix,
# Nearest to prince: marshalling, satsuma, wein, passively, chapelle, metcalfe, warlord, lymphomas,
# Nearest to something: charting, mailing, escapement, transformational, connectives, portuguesa, proper, protolanguage,
# Nearest to hit: tiberian, storing, dazzle, carriage, vlaamse, posing, alveolar, barton,
# Nearest to centre: occupies, claudia, khomeini, hanged, v, nss, chairmen, goodwill,
# Nearest to magazine: gymnast, arran, spine, principles, pave, botham, gairy, farming,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4952 0.0788 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4895 0.0778 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4647 0.0780 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5178 0.0770 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4822 0.0778 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4786 0.0778 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4652 0.0778 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4148 0.0775 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4458 0.0772 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4202 0.0775 sec/batch
# Nearest to zero: est, five, two, four, million, engrams, abaddon, growth,
# Nearest to one: six, four, remey, mister, nine, alejandro, prot, winnie,
# Nearest to six: one, entomologist, seven, evaporated, obispo, sefirot, baptiste, vietnamese,
# Nearest to that: rpc, intuition, isn, flamboyant, stating, stemmed, seeks, sharada,
# Nearest to there: find, intention, genres, trigonometric, terminates, gearloose, satisfy, dichotomy,
# Nearest to years: digests, wolfowitz, september, five, travelled, preferred, maximilian, algeria,
# Nearest to and: simo, conformed, zed, crozier, overlooked, imt, day, show,
# Nearest to s: broz, humid, nadph, gall, proposer, undeniably, simonds, spellman,
# Nearest to channel: rainstorm, bolster, champaign, leftarrow, amusements, lollardy, demobilization, sanctify,
# Nearest to stage: ridge, yerushalayim, siamese, balearic, lp, exception, rotating, pear,
# Nearest to brother: writings, rainier, count, blaurock, nicholson, beatrix, melton, pete,
# Nearest to prince: marshalling, satsuma, wein, chapelle, metcalfe, passively, warlord, lymphomas,
# Nearest to something: escapement, charting, mailing, transformational, protolanguage, connectives, equalization, proper,
# Nearest to hit: tiberian, vlaamse, dazzle, posing, storing, alveolar, scriptwriter, superman,
# Nearest to centre: occupies, khomeini, hanged, nss, claudia, v, goodwill, inland,
# Nearest to magazine: gymnast, spine, arran, pave, botham, gairy, lemay, ripple,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4341 0.0788 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4293 0.0771 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4538 0.0780 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4056 0.0778 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4116 0.0773 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4688 0.0774 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3959 0.0777 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3895 0.0778 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4319 0.0774 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3746 0.0773 sec/batch
# Nearest to zero: five, est, two, four, abaddon, seven, lenape, million,
# Nearest to one: six, four, nine, seven, joris, prot, five, mister,
# Nearest to six: one, seven, entomologist, obispo, sefirot, cbm, four, evaporated,
# Nearest to that: rpc, overtones, sharada, isn, stating, stemmed, seeks, multilateral,
# Nearest to there: terminates, intention, find, gearloose, trigonometric, satisfy, vigesimal, dispassionate,
# Nearest to years: wolfowitz, digests, september, five, travelled, maximilian, disavow, leonel,
# Nearest to and: conformed, simo, overlooked, crozier, zed, show, day, vets,
# Nearest to s: broz, nadph, proposer, barrie, humid, sleng, simonds, undeniably,
# Nearest to channel: bolster, rainstorm, champaign, amusements, leftarrow, technologists, lollardy, demobilization,
# Nearest to stage: yerushalayim, ridge, siamese, testimonium, balearic, lp, blurry, sampler,
# Nearest to brother: writings, pete, beatrix, blaurock, rainier, granddaughter, count, nicholson,
# Nearest to prince: marshalling, satsuma, wein, chapelle, metcalfe, warlord, passively, reigns,
# Nearest to something: escapement, transformational, connectives, protolanguage, proper, disjointed, charting, wilberforce,
# Nearest to hit: storing, vlaamse, dazzle, tiberian, superman, posing, jigsaw, scriptwriter,
# Nearest to centre: occupies, khomeini, nss, hanged, claudia, chairmen, inland, sharman,
# Nearest to magazine: gymnast, arran, spine, pave, botham, kane, lemay, carrie,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3520 0.0780 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3802 0.0777 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3860 0.0770 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3539 0.0777 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3806 0.0777 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3591 0.0778 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3919 0.0772 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3764 0.0788 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3319 0.0768 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3256 0.0756 sec/batch
# Nearest to zero: five, est, two, four, million, seven, three, abaddon,
# Nearest to one: six, four, five, nine, seven, prot, two, remey,
# Nearest to six: one, seven, two, entomologist, four, cbm, obispo, zero,
# Nearest to that: isn, stating, overtones, sharada, multilateral, combatting, seeks, rpc,
# Nearest to there: terminates, intention, find, gearloose, vigesimal, plosive, trigonometric, empties,
# Nearest to years: five, wolfowitz, digests, september, disavow, maximilian, preferred, travelled,
# Nearest to and: zed, their, simo, crozier, conformed, overlooked, cyclops, day,
# Nearest to s: sleng, barrie, broz, guinean, proposer, martius, spellman, humid,
# Nearest to channel: bolster, rainstorm, champaign, amusements, laser, technologists, referrals, internet,
# Nearest to stage: yerushalayim, siamese, ridge, testimonium, balearic, sampler, exception, lp,
# Nearest to brother: writings, pete, count, granddaughter, blaurock, beatrix, consorts, rainier,
# Nearest to prince: marshalling, satsuma, warlord, chapelle, reigns, wein, metcalfe, mnr,
# Nearest to something: escapement, transformational, connectives, protolanguage, mailing, wilberforce, proper, charting,
# Nearest to hit: storing, scriptwriter, vlaamse, dazzle, superman, posing, hollywood, philanthropists,
# Nearest to centre: occupies, khomeini, hanged, nss, chairmen, claudia, viable, goodwill,
# Nearest to magazine: gymnast, arran, spine, pave, carrie, gairy, botham, lemay,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3724 0.0786 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2867 0.0780 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3766 0.0783 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3727 0.0771 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3789 0.0771 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2898 0.0773 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3383 0.0767 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3610 0.0771 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2315 0.0769 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2827 0.0769 sec/batch
# Nearest to zero: five, est, two, four, three, seven, one, nine,
# Nearest to one: six, four, nine, five, seven, eight, two, zero,
# Nearest to six: one, seven, four, two, entomologist, five, zero, baptiste,
# Nearest to that: isn, stating, combatting, subjectively, multilateral, overtones, recommend, seeks,
# Nearest to there: terminates, intention, vigesimal, gearloose, trigonometric, find, straddled, satisfy,
# Nearest to years: five, wolfowitz, digests, disavow, population, september, expectancy, maximilian,
# Nearest to and: simo, zed, conformed, overlooked, cyclops, postulating, dissipate, their,
# Nearest to s: sleng, barrie, proposer, broz, nadph, spellman, viewers, arianespace,
# Nearest to channel: rainstorm, bolster, champaign, amusements, laser, technologists, internet, referrals,
# Nearest to stage: siamese, yerushalayim, testimonium, ridge, sampler, balearic, lp, beauvoir,
# Nearest to brother: count, writings, granddaughter, blaurock, pete, orator, consorts, beatrix,
# Nearest to prince: marshalling, warlord, metcalfe, satsuma, reigns, wein, chapelle, passively,
# Nearest to something: escapement, transformational, protolanguage, wilberforce, connectives, proper, disjointed, charting,
# Nearest to hit: vlaamse, scriptwriter, storing, philanthropists, hollywood, posing, superman, jigsaw,
# Nearest to centre: occupies, nss, hanged, khomeini, chairmen, accumulated, claudia, viable,
# Nearest to magazine: gymnast, spine, arran, pave, carrie, botham, muller, gairy,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2942 0.0784 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2872 0.0779 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3280 0.0381 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2549 0.0777 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2109 0.0776 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2141 0.0774 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2126 0.0769 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1936 0.0770 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2083 0.0774 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1852 0.0775 sec/batch
# Nearest to zero: five, two, est, four, three, one, seven, nine,
# Nearest to one: six, four, five, nine, two, zero, seven, eight,
# Nearest to six: one, seven, four, two, five, entomologist, zero, honecker,
# Nearest to that: multilateral, isn, seeks, stating, subjectively, garciaparra, sharada, combatting,
# Nearest to there: terminates, intention, gearloose, vigesimal, empties, straddled, find, trigonometric,
# Nearest to years: five, wolfowitz, september, leonel, travelled, digests, disavow, population,
# Nearest to and: simo, zed, their, harwood, conformed, overlooked, meticulously, dissipate,
# Nearest to s: sleng, barrie, proposer, broz, viewers, spellman, bertolt, controversially,
# Nearest to channel: rainstorm, bolster, champaign, amusements, internet, laser, referrals, queuing,
# Nearest to stage: yerushalayim, sampler, ridge, siamese, lp, balearic, exception, testimonium,
# Nearest to brother: beatrix, count, consorts, granddaughter, boleslav, moravians, orator, writings,
# Nearest to prince: marshalling, warlord, metcalfe, satsuma, nombre, blunders, wein, mnr,
# Nearest to something: escapement, transformational, protolanguage, disjointed, wilberforce, charting, connectives, proper,
# Nearest to hit: storing, scriptwriter, philanthropists, vlaamse, alveolar, dazzle, superman, bombs,
# Nearest to centre: occupies, nss, khomeini, accumulated, chairmen, hanged, sharman, viable,
# Nearest to magazine: gymnast, spine, arran, pave, quotation, ripple, carrie, botham,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2459 0.0783 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2500 0.0779 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2176 0.0773 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1353 0.0768 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1773 0.0778 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1855 0.0774 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1536 0.0775 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1863 0.0777 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2099 0.0776 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2048 0.0769 sec/batch
# Nearest to zero: five, two, est, four, three, seven, one, nine,
# Nearest to one: six, four, five, nine, two, zero, lusignan, three,
# Nearest to six: one, seven, four, five, two, entomologist, zero, three,
# Nearest to that: isn, seeks, upbringing, multilateral, combatting, stating, sharada, irreducibility,
# Nearest to there: terminates, vigesimal, find, trigonometric, intention, gearloose, satisfy, indexed,
# Nearest to years: five, expectancy, wolfowitz, population, females, take, digests, rate,
# Nearest to and: their, overlooked, conformed, show, simo, meticulously, harwood, zed,
# Nearest to s: sleng, viewers, barrie, spellman, sanctuaries, proposer, bertolt, broz,
# Nearest to channel: rainstorm, champaign, bolster, amusements, internet, laser, queuing, referrals,
# Nearest to stage: siamese, sampler, yerushalayim, exception, ridge, lp, republican, balearic,
# Nearest to brother: beatrix, consorts, moravians, boleslav, granddaughter, count, orator, title,
# Nearest to prince: marshalling, warlord, satsuma, metcalfe, dpp, blunders, nombre, reigns,
# Nearest to something: escapement, charting, protolanguage, transformational, disjointed, wilberforce, curdling, abduct,
# Nearest to hit: philanthropists, vlaamse, scriptwriter, storing, alveolar, posing, scripted, superman,
# Nearest to centre: occupies, accumulated, sharman, nss, viable, chairmen, places, scheme,
# Nearest to magazine: gymnast, carrie, muller, quotation, spine, kane, botham, arran,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1593 0.0783 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2326 0.0772 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2030 0.0773 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1545 0.0766 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1990 0.0772 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1693 0.0775 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2100 0.0771 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1446 0.0764 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1399 0.0779 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1767 0.0771 sec/batch
# Nearest to zero: five, two, est, four, three, one, seven, six,
# Nearest to one: six, four, five, nine, two, seven, zero, three,
# Nearest to six: one, seven, four, five, two, three, zero, entomologist,
# Nearest to that: isn, multilateral, kotoku, subjectively, reducible, combatting, upbringing, overtones,
# Nearest to there: terminates, find, satisfy, vigesimal, intention, gearloose, indexed, straddled,
# Nearest to years: five, expectancy, population, male, females, rate, wolfowitz, female,
# Nearest to and: overlooked, simo, their, dissipate, zed, show, indispensable, resuming,
# Nearest to s: sleng, mathematically, barrie, proposer, ectocervix, hawar, guinean, sanctuaries,
# Nearest to channel: champaign, rainstorm, bolster, laser, internet, amusements, referrals, leftarrow,
# Nearest to stage: siamese, sampler, yerushalayim, balearic, exception, lp, testimonium, republican,
# Nearest to brother: beatrix, consorts, moravians, granddaughter, orator, count, boleslav, bovines,
# Nearest to prince: marshalling, warlord, dpp, metcalfe, blunders, daughter, nombre, satsuma,
# Nearest to something: escapement, protolanguage, wilberforce, disjointed, transformational, observe, charting, abduct,
# Nearest to hit: scriptwriter, philanthropists, storing, scripted, vlaamse, hollywood, alveolar, dazzle,
# Nearest to centre: occupies, sharman, accumulated, nss, chairmen, viable, claudia, mindelo,
# Nearest to magazine: gymnast, carrie, kth, arran, quotation, muller, botham, daily,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2031 0.0780 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1671 0.0773 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1987 0.0766 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1833 0.0774 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1495 0.0778 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1224 0.0773 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1718 0.0770 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1164 0.0779 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1832 0.0781 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1927 0.0771 sec/batch
# Nearest to zero: five, two, four, three, est, one, seven, six,
# Nearest to one: six, four, five, nine, two, seven, zero, eight,
# Nearest to six: one, seven, four, five, two, zero, three, entomologist,
# Nearest to that: kotoku, upbringing, multilateral, isn, seeks, stating, garciaparra, subjectively,
# Nearest to there: terminates, straddled, empties, intention, vigesimal, find, gearloose, probation,
# Nearest to years: five, expectancy, wolfowitz, population, male, briton, two, leonel,
# Nearest to and: their, led, simo, harwood, major, overlooked, lindisfarne, zed,
# Nearest to s: sleng, barrie, spellman, impeccable, hawar, simonds, bertolt, fianc,
# Nearest to channel: rainstorm, bolster, champaign, laser, amusements, internet, referrals, leftarrow,
# Nearest to stage: siamese, sampler, republican, lp, balearic, yerushalayim, exception, beauvoir,
# Nearest to brother: consorts, beatrix, boleslav, granddaughter, moravians, count, orator, daughters,
# Nearest to prince: marshalling, warlord, daughter, dpp, dowland, metcalfe, blunders, nombre,
# Nearest to something: escapement, transformational, wilberforce, charting, protolanguage, disjointed, observe, biafra,
# Nearest to hit: philanthropists, scriptwriter, scripted, vlaamse, hollywood, starred, starters, kfc,
# Nearest to centre: occupies, nss, sharman, accumulated, chairmen, seaport, claudia, viable,
# Nearest to magazine: gymnast, daily, carrie, arran, kth, quotation, muller, published,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2383 0.0786 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1560 0.0776 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1210 0.0774 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1780 0.0763 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0388 0.0764 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1366 0.0775 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1546 0.0768 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1484 0.0773 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1765 0.0169 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1002 0.0771 sec/batch
# Nearest to zero: five, two, four, three, est, one, seven, six,
# Nearest to one: six, four, five, two, nine, zero, seven, three,
# Nearest to six: one, seven, four, five, two, zero, three, entomologist,
# Nearest to that: multilateral, kotoku, garciaparra, subjectively, isn, bultmann, upbringing, seeks,
# Nearest to there: terminates, vigesimal, straddled, empties, indexed, gearloose, find, satisfy,
# Nearest to years: five, expectancy, population, male, rate, wolfowitz, females, female,
# Nearest to and: their, major, overlooked, dissipate, show, simo, microclimates, zed,
# Nearest to s: sleng, barrie, impeccable, hawar, spellman, mathematically, proposer, viewers,
# Nearest to channel: rainstorm, champaign, bolster, internet, amusements, laser, referrals, leftarrow,
# Nearest to stage: siamese, sampler, lp, republican, yerushalayim, exception, balearic, testimonium,
# Nearest to brother: consorts, beatrix, boleslav, moravians, count, orator, ippolito, granddaughter,
# Nearest to prince: marshalling, warlord, metcalfe, dowland, blunders, dpp, satsuma, nombre,
# Nearest to something: escapement, charting, transformational, protolanguage, disjointed, wilberforce, connectives, biafra,
# Nearest to hit: philanthropists, scriptwriter, scripted, hollywood, vlaamse, dazzle, starred, kfc,
# Nearest to centre: occupies, nss, seaport, accumulated, sharman, minneapolis, mindelo, chairmen,
# Nearest to magazine: gymnast, kth, daily, compendium, arran, rating, demeanor, pave,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0873 0.0783 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0659 0.0777 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0983 0.0772 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0532 0.0770 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0779 0.0780 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0236 0.0771 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1253 0.0770 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0746 0.0776 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1124 0.0775 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0263 0.0778 sec/batch
# Nearest to zero: five, two, four, three, one, est, seven, six,
# Nearest to one: six, four, five, two, zero, nine, seven, three,
# Nearest to six: one, seven, four, five, two, zero, three, entomologist,
# Nearest to that: isn, kotoku, upbringing, multilateral, subjectively, bultmann, reducible, recommend,
# Nearest to there: terminates, vigesimal, straddled, fertilization, find, empties, indexed, tiran,
# Nearest to years: five, expectancy, population, rate, male, two, wolfowitz, female,
# Nearest to and: their, overlooked, dissipate, major, the, indispensable, alluvial, simo,
# Nearest to s: sleng, proposer, mathematically, barrie, spellman, hawar, impeccable, cementing,
# Nearest to channel: rainstorm, champaign, bolster, laser, internet, referrals, amusements, queuing,
# Nearest to stage: siamese, republican, lp, sampler, exception, yerushalayim, ridge, balearic,
# Nearest to brother: beatrix, consorts, count, boleslav, moravians, title, granddaughter, daughters,
# Nearest to prince: marshalling, satsuma, metcalfe, dowland, warlord, dpp, blunders, carlists,
# Nearest to something: escapement, charting, protolanguage, disjointed, transformational, wilberforce, curdling, mailing,
# Nearest to hit: philanthropists, scripted, scriptwriter, eps, vlaamse, starters, hollywood, storing,
# Nearest to centre: occupies, seaport, sharman, nss, accumulated, places, historic, claudia,
# Nearest to magazine: daily, gymnast, kth, compendium, rating, principles, ripple, published,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0309 0.0783 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0343 0.0774 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0316 0.0772 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0657 0.0778 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0723 0.0776 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0559 0.0777 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0681 0.0778 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1127 0.0774 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0311 0.0775 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0544 0.0771 sec/batch
# Nearest to zero: five, two, three, four, one, est, seven, six,
# Nearest to one: six, four, five, two, zero, nine, seven, three,
# Nearest to six: one, four, seven, five, two, three, zero, eight,
# Nearest to that: isn, reducible, kotoku, upbringing, sinners, garciaparra, irreducibility, bultmann,
# Nearest to there: terminates, satisfy, greater, find, straddled, vigesimal, fertilization, empties,
# Nearest to years: five, expectancy, population, male, rate, four, females, female,
# Nearest to and: their, overlooked, indispensable, major, show, the, ucd, zed,
# Nearest to s: sleng, barrie, mathematically, dl, impeccable, hawar, unproven, proposer,
# Nearest to channel: champaign, rainstorm, bolster, internet, laser, referrals, amusements, leftarrow,
# Nearest to stage: siamese, republican, sampler, lp, yerushalayim, exception, beauvoir, depeche,
# Nearest to brother: beatrix, consorts, count, boleslav, moravians, granddaughter, title, daughters,
# Nearest to prince: marshalling, satsuma, dowland, metcalfe, dpp, blunders, warlord, carlists,
# Nearest to something: escapement, charting, proper, protolanguage, transformational, disjointed, curdling, observe,
# Nearest to hit: philanthropists, scripted, vlaamse, scriptwriter, eps, alveolar, storing, starters,
# Nearest to centre: seaport, sharman, nss, occupies, accumulated, mindelo, cbd, historic,
# Nearest to magazine: daily, published, gymnast, kth, weekly, principles, compendium, arran,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0679 0.0788 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0424 0.0771 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0802 0.0774 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0512 0.0774 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0695 0.0774 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0478 0.0772 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0783 0.0774 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0768 0.0775 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0844 0.0773 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0624 0.0778 sec/batch
# Nearest to zero: five, two, four, three, one, est, seven, nine,
# Nearest to one: six, four, five, two, zero, seven, nine, three,
# Nearest to six: one, seven, four, five, two, zero, three, eight,
# Nearest to that: kotoku, isn, reducible, bultmann, garciaparra, survived, subjectively, multilateral,
# Nearest to there: terminates, straddled, empties, find, intention, greater, vigesimal, satisfy,
# Nearest to years: five, expectancy, population, rate, male, four, two, six,
# Nearest to and: their, the, overlooked, indispensable, major, simo, jiangsu, motivates,
# Nearest to s: sleng, barrie, guinean, sanctuaries, mathematically, caesura, simonds, hawar,
# Nearest to channel: rainstorm, champaign, bolster, laser, internet, referrals, touchscreen, amusements,
# Nearest to stage: siamese, sampler, yerushalayim, republican, exception, lp, balearic, testimonium,
# Nearest to brother: consorts, beatrix, count, boleslav, moravians, granddaughter, daughters, orator,
# Nearest to prince: marshalling, dpp, dowland, daughter, satsuma, blunders, warlord, metcalfe,
# Nearest to something: escapement, charting, disjointed, wilberforce, curdling, transformational, mailing, proper,
# Nearest to hit: philanthropists, scripted, discriminant, carriage, vlaamse, storing, experimenter, eps,
# Nearest to centre: seaport, nss, sharman, occupies, cbd, accumulated, esoc, minneapolis,
# Nearest to magazine: daily, published, weekly, gymnast, demeanor, kth, principles, compendium,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0391 0.0791 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0516 0.0773 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0595 0.0777 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0812 0.0774 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0600 0.0773 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1517 0.0773 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1349 0.0776 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0491 0.0782 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0109 0.0777 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0820 0.0772 sec/batch
# Nearest to zero: five, two, four, three, one, est, seven, six,
# Nearest to one: six, four, zero, two, five, seven, nine, three,
# Nearest to six: one, seven, four, five, two, three, zero, eight,
# Nearest to that: multilateral, kotoku, garciaparra, reducible, bultmann, survived, isn, subjectively,
# Nearest to there: terminates, find, empties, nazca, straddled, vigesimal, greater, condominiums,
# Nearest to years: five, expectancy, population, male, rate, two, four, six,
# Nearest to and: their, overlooked, the, zed, dissipate, simo, toughness, show,
# Nearest to s: sleng, barrie, mathematically, impeccable, hawar, bertolt, sanctuaries, sideshow,
# Nearest to channel: rainstorm, champaign, bolster, internet, referrals, touchscreen, laser, leftarrow,
# Nearest to stage: siamese, sampler, republican, lp, yerushalayim, exception, depeche, judi,
# Nearest to brother: consorts, beatrix, count, boleslav, granddaughter, moravians, daughters, orator,
# Nearest to prince: marshalling, dowland, satsuma, dpp, blunders, daughter, carlists, metcalfe,
# Nearest to something: escapement, charting, wilberforce, proper, disjointed, transformational, biafra, protolanguage,
# Nearest to hit: philanthropists, scripted, eps, scriptwriter, vlaamse, hollywood, sinbad, discriminant,
# Nearest to centre: seaport, nss, sharman, occupies, cbd, accumulated, minneapolis, vengeful,
# Nearest to magazine: daily, demeanor, weekly, published, gymnast, compendium, principles, kth,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9535 0.0791 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0157 0.0772 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0595 0.0771 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0658 0.0768 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0599 0.0779 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0450 0.0758 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0092 0.0775 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9544 0.0770 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0231 0.0771 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9636 0.0771 sec/batch
# Nearest to zero: five, two, four, three, one, seven, six, nine,
# Nearest to one: six, four, zero, two, seven, nine, five, three,
# Nearest to six: one, seven, four, five, two, zero, three, eight,
# Nearest to that: kotoku, multilateral, bultmann, isn, reducible, survived, garciaparra, technologically,
# Nearest to there: vigesimal, find, greater, terminates, empties, straddled, tiran, nazca,
# Nearest to years: five, expectancy, male, population, rate, migration, two, disavow,
# Nearest to and: their, overlooked, the, indispensable, zed, toughness, silk, major,
# Nearest to s: sleng, barrie, mathematically, tout, spellman, simonds, hawar, unproven,
# Nearest to channel: rainstorm, champaign, bolster, internet, referrals, touchscreen, laser, amusements,
# Nearest to stage: sampler, siamese, republican, lp, yerushalayim, exception, erection, thrill,
# Nearest to brother: consorts, count, beatrix, boleslav, daughters, moravians, granddaughter, mental,
# Nearest to prince: marshalling, satsuma, dowland, dpp, metcalfe, carlists, blunders, daughter,
# Nearest to something: escapement, charting, proper, transformational, curdling, disjointed, biafra, wilberforce,
# Nearest to hit: philanthropists, eps, scriptwriter, scripted, hollywood, sinbad, delray, belfast,
# Nearest to centre: seaport, nss, cbd, occupies, minneapolis, sharman, accumulated, historic,
# Nearest to magazine: daily, demeanor, weekly, principles, dusseldorf, published, gymnast, vendetta,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0047 0.0785 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9504 0.0776 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0292 0.0770 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0279 0.0772 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0302 0.0768 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0046 0.0779 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9338 0.0771 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9928 0.0771 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9001 0.0774 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0159 0.0770 sec/batch
# Nearest to zero: five, two, four, three, one, seven, nine, six,
# Nearest to one: four, six, zero, two, nine, five, three, seven,
# Nearest to six: one, four, seven, five, two, three, zero, eight,
# Nearest to that: reducible, multilateral, kotoku, isn, garciaparra, bultmann, about, decide,
# Nearest to there: is, vigesimal, greater, terminates, straddled, indexed, find, condominiums,
# Nearest to years: five, expectancy, male, population, rate, migration, two, four,
# Nearest to and: their, the, ucd, indispensable, overlooked, major, including, zed,
# Nearest to s: sleng, barrie, has, sanctuaries, mathematically, cementing, spellman, simonds,
# Nearest to channel: rainstorm, champaign, internet, bolster, referrals, touchscreen, shetland, laser,
# Nearest to stage: sampler, siamese, republican, exception, yerushalayim, lp, judi, balearic,
# Nearest to brother: beatrix, consorts, count, boleslav, daughters, moravians, granddaughter, ippolito,
# Nearest to prince: marshalling, satsuma, dowland, metcalfe, dpp, lordship, carlists, wali,
# Nearest to something: escapement, charting, disjointed, proper, curdling, biafra, mailing, protolanguage,
# Nearest to hit: eps, philanthropists, pitch, starters, discriminant, scripted, experimenter, baserunner,
# Nearest to centre: seaport, cbd, nss, occupies, accumulated, sharman, esoc, minneapolis,
# Nearest to magazine: daily, weekly, published, principles, demeanor, rating, compendium, dusseldorf,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9869 0.0788 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9684 0.0771 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9797 0.0772 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9668 0.0773 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0206 0.0774 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9519 0.0763 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9912 0.0767 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9805 0.0764 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9885 0.0779 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9959 0.0775 sec/batch
# Nearest to zero: five, two, four, three, one, seven, nine, six,
# Nearest to one: four, six, nine, zero, two, seven, five, three,
# Nearest to six: one, seven, four, five, three, two, zero, eight,
# Nearest to that: reducible, kotoku, isn, be, survived, multilateral, bultmann, irreducibility,
# Nearest to there: is, find, greater, terminates, indexed, answer, vigesimal, valid,
# Nearest to years: five, expectancy, male, population, rate, two, migration, last,
# Nearest to and: their, the, ucd, overlooked, crozier, including, indispensable, major,
# Nearest to s: sleng, barrie, has, biographer, dl, tout, sideshow, ammanati,
# Nearest to channel: rainstorm, champaign, internet, referrals, bolster, laser, touchscreen, shetland,
# Nearest to stage: sampler, siamese, yerushalayim, republican, lp, exception, balearic, judi,
# Nearest to brother: beatrix, consorts, count, boleslav, daughters, moravians, granddaughter, orator,
# Nearest to prince: satsuma, marshalling, dowland, metcalfe, lordship, daughter, carlists, blunders,
# Nearest to something: escapement, proper, charting, disjointed, biafra, curdling, protolanguage, wilberforce,
# Nearest to hit: philanthropists, eps, discriminant, implausible, scripted, hollywood, dandridge, sinbad,
# Nearest to centre: seaport, cbd, esoc, sharman, nss, occupies, accumulated, historic,
# Nearest to magazine: daily, weekly, principles, published, demeanor, compendium, dusseldorf, vendetta,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0344 0.0787 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9739 0.0773 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9887 0.0768 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0205 0.0771 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0214 0.0768 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0020 0.0774 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9846 0.0776 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9503 0.0772 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9440 0.0771 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0192 0.0782 sec/batch
# Nearest to zero: five, two, three, four, one, seven, six, nine,
# Nearest to one: six, four, nine, seven, zero, two, five, three,
# Nearest to six: one, seven, four, five, three, two, zero, eight,
# Nearest to that: reducible, kotoku, multilateral, have, be, decide, survived, depend,
# Nearest to there: is, find, greater, terminates, differ, straddled, have, answer,
# Nearest to years: five, expectancy, male, population, rate, zero, migration, two,
# Nearest to and: their, the, as, by, including, of, main, major,
# Nearest to s: sleng, barrie, of, has, ammanati, in, guinean, unproven,
# Nearest to channel: rainstorm, champaign, referrals, touchscreen, internet, bolster, laser, queuing,
# Nearest to stage: siamese, republican, yerushalayim, sampler, balearic, exception, lp, judi,
# Nearest to brother: consorts, beatrix, daughters, boleslav, count, moravians, mcfowl, orator,
# Nearest to prince: satsuma, marshalling, dowland, lordship, metcalfe, daughter, princess, wenzel,
# Nearest to something: escapement, disjointed, proper, charting, biafra, mailing, wilberforce, protolanguage,
# Nearest to hit: philanthropists, eps, discriminant, implausible, hollywood, dandridge, sinbad, scripted,
# Nearest to centre: seaport, cbd, esoc, sharman, nss, occupies, mindelo, accumulated,
# Nearest to magazine: daily, weekly, demeanor, principles, published, compendium, dusseldorf, rating,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9787 0.0788 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0883 0.0773 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0381 0.0775 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0558 0.0765 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9347 0.0766 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9382 0.0770 sec/batch
# ...
# Nearest to centre: seaport, cbd, esoc, islamic, near, pall, southwark, mindelo,
# Nearest to magazine: weekly, magazines, daily, dusseldorf, spine, published, breast, cloves,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8853 0.0787 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7610 0.0776 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8175 0.0777 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7643 0.0774 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8311 0.0769 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8686 0.0772 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8722 0.0776 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8289 0.0775 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8657 0.0779 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9030 0.0769 sec/batch
# Nearest to zero: five, two, four, one, three, six, seven, nine,
# Nearest to one: four, six, nine, two, zero, three, seven, five,
# Nearest to six: one, four, seven, five, three, zero, two, eight,
# Nearest to that: be, it, in, a, to, would, the, have,
# Nearest to there: are, is, have, of, non, greater, any, find,
# Nearest to years: five, zero, expectancy, age, population, male, two, six,
# Nearest to and: the, of, a, as, in, on, other, with,
# Nearest to s: in, the, and, due, of, is, has, two,
# Nearest to channel: rainstorm, referrals, privatized, shetland, frontier, touchscreen, bolster, charlottetown,
# Nearest to stage: judi, coherent, grueling, sampler, lp, theatre, lightest, gzip,
# Nearest to brother: mcfowl, became, consorts, count, minivan, beatrix, daughters, whitworth,
# Nearest to prince: princess, satsuma, lighthouse, metcalfe, marshalling, curators, dowland, transcription,
# Nearest to something: proper, disjointed, escapement, curdling, stump, charting, get, wilberforce,
# Nearest to hit: baserunner, hitting, delray, hits, next, nu, breakout, pitch,
# Nearest to centre: seaport, cbd, esoc, islamic, pall, southwark, mindelo, near,
# Nearest to magazine: weekly, daily, magazines, published, dusseldorf, breast, rating, taz,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8263 0.0784 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8712 0.0778 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8624 0.0774 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8500 0.0776 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8513 0.0773 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8664 0.0770 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8503 0.0776 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8447 0.0771 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8799 0.0772 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8943 0.0771 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: four, six, nine, two, zero, seven, three, five,
# Nearest to six: one, seven, four, five, three, zero, two, eight,
# Nearest to that: be, it, in, to, a, would, survived, the,
# Nearest to there: are, have, is, of, find, monastir, greater, differ,
# Nearest to years: five, zero, expectancy, population, male, age, six, two,
# Nearest to and: the, of, as, a, in, other, with, their,
# Nearest to s: in, is, the, has, of, two, sleng, and,
# Nearest to channel: rainstorm, touchscreen, frontier, referrals, privatized, shetland, bolster, channels,
# Nearest to stage: judi, coherent, grueling, sampler, moesia, theatre, exception, polemic,
# Nearest to brother: became, mcfowl, consorts, count, daughters, minivan, beatrix, bovines,
# Nearest to prince: princess, satsuma, lighthouse, consort, marshalling, ruler, curators, dowland,
# Nearest to something: proper, wilberforce, escapement, disjointed, stump, charting, curdling, mailing,
# Nearest to hit: baserunner, hits, delray, next, hitting, daro, nu, breakout,
# Nearest to centre: cbd, seaport, esoc, islamic, pall, mindelo, southwark, vengeful,
# Nearest to magazine: magazines, weekly, daily, published, dusseldorf, breast, cloves, taz,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8672 0.0785 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8342 0.0775 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8312 0.0775 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8373 0.0774 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9318 0.0775 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8685 0.0773 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9544 0.0779 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8753 0.0773 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9166 0.0774 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8556 0.0771 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: four, six, nine, zero, two, seven, three, five,
# Nearest to six: one, seven, four, five, three, zero, two, eight,
# Nearest to that: be, it, a, to, in, would, survived, because,
# Nearest to there: are, is, have, of, monastir, differ, scientists, find,
# Nearest to years: five, zero, expectancy, population, male, age, two, six,
# Nearest to and: the, of, a, as, in, with, other, on,
# Nearest to s: in, the, and, of, due, sleng, is, has,
# Nearest to channel: referrals, rainstorm, touchscreen, privatized, frontier, bolster, shetland, internet,
# Nearest to stage: judi, grueling, coherent, honors, theatre, polemic, sampler, republican,
# Nearest to brother: mcfowl, consorts, became, count, daughters, whitworth, bovines, mental,
# Nearest to prince: princess, satsuma, lighthouse, dowland, transcription, consort, marshalling, individually,
# Nearest to something: proper, disjointed, wilberforce, should, escapement, stump, curdling, get,
# Nearest to hit: baserunner, next, hitting, delray, hits, nu, breakout, daro,
# Nearest to centre: seaport, cbd, islamic, esoc, near, pall, mindelo, southwark,
# Nearest to magazine: magazines, weekly, daily, breast, cloves, dusseldorf, published, spine,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8414 0.0778 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8591 0.0770 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8085 0.0774 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8845 0.0774 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8511 0.0778 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8518 0.0770 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8741 0.0518 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8242 0.0777 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8201 0.0770 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8531 0.0776 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: six, four, nine, seven, two, five, zero, three,
# Nearest to six: one, seven, four, five, three, zero, two, eight,
# Nearest to that: be, it, in, to, a, would, because, survived,
# Nearest to there: are, is, of, have, where, the, demesne, or,
# Nearest to years: five, zero, expectancy, age, male, last, population, two,
# Nearest to and: the, a, of, in, as, with, other, by,
# Nearest to s: in, the, and, is, sleng, of, as, due,
# Nearest to channel: referrals, rainstorm, touchscreen, privatized, bolster, frontier, shetland, subpages,
# Nearest to stage: judi, grueling, lightest, coherent, gzip, sampler, moesia, schematic,
# Nearest to brother: mcfowl, became, consorts, daughters, count, whitworth, eldest, bovines,
# Nearest to prince: princess, satsuma, lighthouse, consort, ruler, dowland, dpp, individually,
# Nearest to something: disjointed, proper, should, stump, escapement, wilberforce, mailing, charting,
# Nearest to hit: delray, hits, baserunner, next, hitting, daro, nu, breakout,
# Nearest to centre: cbd, seaport, islamic, esoc, pall, mindelo, southwark, wilmslow,
# Nearest to magazine: weekly, magazines, daily, breast, cloves, spine, published, dusseldorf,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8182 0.0788 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8124 0.0776 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7882 0.0776 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8528 0.0770 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8387 0.0771 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8317 0.0774 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8736 0.0770 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7161 0.0777 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8292 0.0770 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7829 0.0773 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: four, six, nine, zero, two, three, five, seven,
# Nearest to six: one, seven, four, five, three, zero, two, eight,
# Nearest to that: be, it, in, a, to, would, because, the,
# Nearest to there: are, is, have, of, be, or, any, differ,
# Nearest to years: five, zero, age, expectancy, population, male, two, total,
# Nearest to and: the, of, a, in, as, with, other, is,
# Nearest to s: in, and, the, has, is, of, due, two,
# Nearest to channel: referrals, touchscreen, rainstorm, channels, privatized, shetland, subpages, bolster,
# Nearest to stage: judi, lightest, grueling, coherent, honors, sampler, theatre, gzip,
# Nearest to brother: mcfowl, consorts, became, whitworth, minivan, count, daughters, beatrix,
# Nearest to prince: princess, satsuma, lighthouse, marshalling, dowland, consort, metcalfe, dpp,
# Nearest to something: disjointed, proper, escapement, should, get, wilberforce, stump, curdling,
# Nearest to hit: hits, baserunner, hitting, next, delray, daro, breakout, quantify,
# Nearest to centre: cbd, seaport, islamic, esoc, pall, near, mindelo, southwark,
# Nearest to magazine: weekly, magazines, daily, published, breast, cloves, dusseldorf, spine,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7816 0.0782 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8190 0.0771 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8545 0.0775 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7896 0.0772 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8342 0.0775 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9026 0.0776 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8291 0.0785 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8366 0.0774 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8303 0.0775 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8384 0.0774 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: four, nine, six, two, zero, three, seven, five,
# Nearest to six: one, seven, four, five, three, zero, two, eight,
# Nearest to that: be, in, to, it, a, the, been, would,
# Nearest to there: are, have, is, of, any, be, the, and,
# Nearest to years: five, zero, age, expectancy, male, total, two, population,
# Nearest to and: the, of, a, with, in, other, as, their,
# Nearest to s: in, and, is, the, of, a, two, has,
# Nearest to channel: referrals, touchscreen, rainstorm, privatized, frontier, shetland, channels, champaign,
# Nearest to stage: judi, grueling, coherent, lightest, honors, polemic, theatre, gzip,
# Nearest to brother: mcfowl, consorts, became, daughters, whitworth, minivan, bovines, fab,
# Nearest to prince: princess, satsuma, consort, lighthouse, ruler, individually, dowland, dpp,
# Nearest to something: proper, escapement, stump, disjointed, should, get, wilberforce, charting,
# Nearest to hit: hits, baserunner, hitting, next, nu, delray, eps, quantify,
# Nearest to centre: cbd, seaport, esoc, islamic, pall, mindelo, southwark, guide,
# Nearest to magazine: weekly, magazines, daily, published, breast, dusseldorf, cloves, pawson,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8453 0.0785 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8492 0.0775 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8399 0.0774 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8380 0.0769 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8750 0.0773 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8688 0.0773 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8272 0.0774 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8562 0.0774 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8203 0.0772 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8081 0.0774 sec/batch
# Nearest to zero: five, two, one, four, three, six, seven, nine,
# Nearest to one: four, six, two, nine, zero, three, seven, five,
# Nearest to six: one, seven, four, three, five, zero, two, eight,
# Nearest to that: be, it, a, in, to, would, the, have,
# Nearest to there: are, have, is, of, any, be, or, in,
# Nearest to years: five, zero, expectancy, male, population, six, age, two,
# Nearest to and: the, of, in, as, other, a, with, their,
# Nearest to s: in, the, and, of, has, due, is, two,
# Nearest to channel: referrals, touchscreen, channels, rainstorm, privatized, bolster, frontier, subpages,
# Nearest to stage: judi, grueling, lightest, polemic, coherent, honors, theatre, sampler,
# Nearest to brother: mcfowl, became, consorts, daughters, whitworth, minivan, bovines, fab,
# Nearest to prince: princess, satsuma, lighthouse, consort, dowland, individually, ruler, transcription,
# Nearest to something: proper, escapement, wilberforce, disjointed, should, stump, get, valign,
# Nearest to hit: hits, hitting, baserunner, next, delray, nu, eps, daro,
# Nearest to centre: seaport, esoc, cbd, islamic, pall, mindelo, near, guide,
# Nearest to magazine: magazines, weekly, daily, published, breast, cloves, vento, dusseldorf,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8628 0.0787 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8052 0.0779 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9410 0.0772 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9059 0.0775 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8909 0.0772 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8039 0.0771 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7852 0.0772 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8426 0.0774 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7584 0.0781 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8381 0.0778 sec/batch
# Nearest to zero: five, two, one, four, six, three, seven, nine,
# Nearest to one: four, six, nine, seven, two, zero, three, five,
# Nearest to six: one, seven, four, three, five, zero, two, eight,
# Nearest to that: be, a, it, in, would, to, the, because,
# Nearest to there: is, are, have, of, be, the, in, or,
# Nearest to years: five, zero, male, expectancy, total, population, two, age,
# Nearest to and: the, of, in, a, with, as, other, on,
# Nearest to s: in, the, and, of, a, is, two, at,
# Nearest to channel: referrals, touchscreen, rainstorm, channels, frontier, shetland, privatized, subpages,
# Nearest to stage: judi, grueling, honors, theatre, lightest, polemic, coherent, sampler,
# Nearest to brother: mcfowl, became, whitworth, consorts, daughters, minivan, bovines, mental,
# Nearest to prince: princess, satsuma, lighthouse, dowland, consort, transcription, individually, dpp,
# Nearest to something: escapement, wilberforce, stump, proper, disjointed, get, enemies, should,
# Nearest to hit: hits, baserunner, hitting, next, delray, nu, daro, breakout,
# Nearest to centre: islamic, seaport, cbd, esoc, pall, near, mindelo, southwark,
# Nearest to magazine: weekly, magazines, daily, breast, cloves, published, demeanor, pawson,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8429 0.0791 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8035 0.0775 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
